# %% [markdown]
# # FDS-G1 Companion D: Likelihood and Falsification Demo
#
# This notebook runs the compressed-data demonstration for the likelihood-ready finite screen-capacity residual framework. Replace the demo CSV files with real SN/BAO/growth/local-gravity data vectors and covariance matrices for production inference.

# %%
import os, sys
ROOT = os.path.abspath('..') if os.path.basename(os.getcwd())=='notebooks' else os.getcwd()
CODE = os.path.join(ROOT, 'code')
sys.path.insert(0, CODE)
import fds_g1_likelihood_falsification_demo as demo

# %%
demo.main()

# %%
import pandas as pd, os
pd.read_csv(os.path.join(ROOT, 'data', 'model_comparison.csv'))
